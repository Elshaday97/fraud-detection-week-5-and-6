# %%
# Fix imports when running from notebooks/ folder
import sys
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Added to path: /Users/elshaday/DEV/10Academy/fraud-detection-week-5-and-6
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import src.data.loader as loader
import src.data.preprocessor as preprocessor
from scripts.constants import CLEAN_FRAUD_DATA_FILE_NAME, CLEAN_DATA_DIR, Fraud_Data_Columns
import src.data.features as feature_engineer
from tabulate import tabulate

# %%
data_loader = loader.DataLoader()
fraud_df = data_loader.load_csv(file_name=CLEAN_FRAUD_DATA_FILE_NAME, file_path=CLEAN_DATA_DIR)
# Out:
# Loaded ../data/processed/fraud_data_clean.csv to dataframe!

# %%
feat_engineer = feature_engineer.FeatEngineer(fraud_df)
transformed_df = feat_engineer.transform_all()
transformed_df.info()
print(tabulate(transformed_df.tail(), headers="keys", tablefmt="grid"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151112 entries, 31545 to 42662
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         151112 non-null  int64
#  1   user_id            151112 non-null  int64
#  2   signup_time        151112 non-null  datetime64[ns]
#  3   purchase_time      151112 non-null  datetime64[ns]
#  4   purchase_value     151112 non-null  int64
#  5   device_id          151112 non-null  object
#  6   source             151112 non-null  object
#  7   browser            151112 non-null  object
#  8   sex                151112 non-null  object
#  9   age                151112 non-null  int64
#  10  ip_address         151112 non-null  float64
#  11  class              151112 non-null  int64
#  12  ip_int             151112 non-null  int64
#  13  country            151112 non-null  object
#  14  hour_of_day        151112 non-null  int32
# ...

# %%
data_processor = preprocessor.DataPreProcessor()
scaled_features = data_processor.scale_features(transformed_df)
