# %%
# Fix imports when running from notebooks/ folder
import sys
from pathlib import Path

project_root = Path.cwd().parent 
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

print(f"Added to path: {project_root}")

# %load_ext autoreload
# %autoreload 2
# Out:
# Added to path: /Users/elshaday/DEV/10Academy/fraud-detection-week-5-and-6

# %%
import src.data.loader as loader
from scripts.constants import (
    CLEAN_FRAUD_DATA_FILE_NAME,
    CLEAN_DATA_DIR,
)
import src.features.features as feature_engineer
from tabulate import tabulate

# %%
data_loader = loader.DataLoader()
fraud_df = data_loader.load_csv(file_name=CLEAN_FRAUD_DATA_FILE_NAME, file_path=CLEAN_DATA_DIR, should_parse_dates=True)
# Out:
# Loaded ../data/processed/fraud_data_clean.csv to dataframe!

# %%
feat_engineer = feature_engineer.FeatEngineer(fraud_df)
transformed_df = feat_engineer.transform_all()
transformed_df.info()
print(tabulate(transformed_df.tail(), headers="keys", tablefmt="grid"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151112 entries, 31545 to 42662
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   user_id            151112 non-null  int64
#  1   signup_time        151112 non-null  datetime64[ns]
#  2   purchase_time      151112 non-null  datetime64[ns]
#  3   purchase_value     151112 non-null  int64
#  4   device_id          151112 non-null  object
#  5   source             151112 non-null  object
#  6   browser            151112 non-null  object
#  7   sex                151112 non-null  object
#  8   age                151112 non-null  int64
#  9   ip_address         151112 non-null  float64
#  10  class              151112 non-null  int64
#  11  ip_int             151112 non-null  int64
#  12  country            151112 non-null  object
#  13  hour_of_day        151112 non-null  int32
#  14  day_of_week        151112 non-null  int32
# ...

# %%
# Save final data with engineered features
data_loader.save_csv(transformed_df, file_name=CLEAN_FRAUD_DATA_FILE_NAME)
# Out:
# Saved dataframe to ../data/processed/fraud_data_clean.csv to successfully!
